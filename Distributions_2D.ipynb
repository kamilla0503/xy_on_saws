# %%
import matplotlib.pyplot as plt
import random
import numpy as np

import pandas as pd
from matplotlib.ticker import LogFormatter 
from scipy.optimize import curve_fit
from pathlib import Path
import matplotlib.colors
from matplotlib import ticker, cm
import pickle

import os                                                                   
import glob

import seaborn as sns
from scipy.stats import norm
#%matplotlib notebook

# %%
 
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.270000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.27")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.280000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.28")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.285000_0.000000_2500.txt", skiprows=2)
#plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.285")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.290000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.29")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.295000_0.000000_2500.txt", skiprows=2)
#plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.295")
 
data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.300000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.3")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.310000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.31")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.315000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.315")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.317000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.317")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.320000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.32", c = "k")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.330000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.33")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.340000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.34")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.350000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.35")
 
plt.title(r"Distribution of cos$\theta$  for N = 2500 ", fontsize=22)

plt.xlabel(r'cos$ \theta$', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)


plt.savefig("Thesis/Images/distr_cos_2500.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.270000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.27")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.280000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.28")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.290000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.29")
 
data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.300000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.3")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.310000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.31")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.320000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.32", c = "k")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.325000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.325", c = "k")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.330000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.33")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.340000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.34")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.350000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.35")
 
plt.title(r"Distribution of cos$\theta$  for N = 1600 ", fontsize=22)

plt.xlabel(r'cos$ \theta$', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)


plt.savefig("Thesis/Images/distr_cos_1600.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.270000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.27")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.280000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.28")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.290000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.29")
 
data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.300000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.3")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.303000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.303")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.305000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.305")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.307000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "*", c = "purple", label = r"J = 1.307")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.308000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.308")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.309000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.309")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.310000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.31")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.320000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.32", c = "k")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.330000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.33")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.340000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.34")

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.350000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.35")
 
plt.title(r"Distribution of cos$\theta$  for N = 4900 ", fontsize=22)

plt.xlabel(r'cos$ \theta$', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)


plt.savefig("Thesis/Images/distr_cos_4900.png", bbox_inches='tight')

# %%
 
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("CPP/Distributions1/Counts_E_1.270000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.27")

data_np = np.loadtxt("CPP/Distributions1/Counts_E_1.275000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.275")

data_np = np.loadtxt("CPP/Distributions1/Counts_E_1.280000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.28")

data_np = np.loadtxt("CPP/Distributions1/Counts_E_1.285000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.285")
 
data_np = np.loadtxt("CPP/Distributions1/Counts_E_1.290000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.29")

data_np = np.loadtxt("CPP/Distributions1/Counts_E_1.295000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.295")
 
data_np = np.loadtxt("CPP/Distributions1/Counts_E_1.300000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.3")

data_np = np.loadtxt("CPP/Distributions1/Counts_E_1.320000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.32")

data_np = np.loadtxt("CPP/Distributions1/Counts_E_1.350000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.35")
 
plt.title(r"Distribution of  e for N = 2500 ", fontsize=22)

plt.xlabel(r'$ e$', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)


#plt.savefig("Thesis/Images/distr_energy_2500.png", bbox_inches='tight')

# %%
 
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.270000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.27")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.275000_0.000000_2500.txt", skiprows=2)
#plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.275")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.280000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.28")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.285000_0.000000_2500.txt", skiprows=2)
#plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.285")
 
data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.290000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.29")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.295000_0.000000_2500.txt", skiprows=2)
#plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.295")
 
data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.300000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.3")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.310000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.31")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.315000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.315")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.317000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.317")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.320000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.32", c= "k")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.330000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.33")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.340000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.34")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.350000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.35")
 
plt.title(r"Distribution of  e for N = 2500 ", fontsize=22)

plt.xlabel(r'$ e$', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)


plt.savefig("Thesis/Images/distr_energy_2500.png", bbox_inches='tight')

# %%
 
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("CPP/Distributions/Counts_mag2_1.270000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.27")
 
data_np = np.loadtxt("CPP/Distributions/Counts_mag2_1.290000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.29")

data_np = np.loadtxt("CPP/Distributions/Counts_mag2_1.295000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.295")
 
data_np = np.loadtxt("CPP/Distributions/Counts_mag2_1.300000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.3")

data_np = np.loadtxt("CPP/Distributions/Counts_mag2_1.320000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.32")
 
plt.title(r"Distribution of $\langle m^2 \rangle$  for N = 2500 ", fontsize=22)

plt.xlabel(r'$ \langle m^2 \rangle$', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)


plt.savefig("Thesis/Images/distr_mag2_2500.png", bbox_inches='tight')

# %%
 
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.270000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.27")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.280000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.28")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.290000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.29")

 
data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.300000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.3")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.310000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.31")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.320000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.32" )

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.325000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.325", c= "k")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.330000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.33")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.340000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.34")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.350000_0.000000_1600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.35")
 
plt.title(r"Distribution of  e for N = 1600 ", fontsize=22)

plt.xlabel(r'$ e$', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)


plt.savefig("Thesis/Images/distr_energy_1600.png", bbox_inches='tight')

# %%
 
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.270000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.27")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.280000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.28")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.290000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.29")

 
data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.300000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.3")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.303000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.303")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.305000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.305")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.307000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.307", c = "purple", ms = 10)

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.308000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.308")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.309000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.309")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.310000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.31")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.320000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.32", c= "k")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.330000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.33")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.340000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.34")

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.350000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 1.35")
 
plt.title(r"Distribution of  $ \langle e \rangle$ for N = 4900 ", fontsize=22)

plt.xlabel(r'$  \langle e \rangle $', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)


plt.savefig("Thesis/Images/distr_energy_4900.png", bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 2, figsize=(13,10)) #,  sharey='row')
axes = axes.reshape(-1)

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.307000_0.000000_4900_34200000000.txt", skiprows=2)
axes[0].plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", c = "purple")
axes[0].set_title(r"$N_{steps}=3.42 \times 10^{10}$", fontsize=24)

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.307000_0.000000_4900_82400000000.txt", skiprows=2)
axes[1].plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "*", c = "purple")
axes[1].set_title(r"$N_{steps}=8.24 \times 10^{10}$", fontsize=24)

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.307000_0.000000_4900_116800000000.txt", skiprows=2)
axes[2].plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "*", c = "purple")
axes[2].set_title(r"$N_{steps}=11.6 \times 11.6^{10}$", fontsize=24)

data_np = np.loadtxt("CPP/Distributions2/Counts_E_1.307000_0.000000_4900.txt", skiprows=2)
axes[3].plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "*", c = "purple")
axes[3].set_title(r"$N_{steps}=20 \times 10^{10}$", fontsize=24)

for i in range(4):
    axes[i].set_xlabel(r"$ \langle e \rangle$", fontsize=22)
    axes[i].tick_params(axis='x', labelsize=22) 
    axes[i].tick_params(axis='y', labelsize=22) 
    
        
plt.tight_layout()

plt.savefig("Thesis/Images/distr_energy_4900_time.png", bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 2, figsize=(13,10)) #,  sharey='row')
axes = axes.reshape(-1)

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.305000_0.000000_4900.txt", skiprows=2)
axes[0].plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "*", c = "brown")
axes[0].set_title(r"$J = 1.305$", fontsize=24)


data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.307000_0.000000_4900.txt", skiprows=2)
axes[1].plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "*", c = "purple", label = r"J = 1.307")
axes[1].set_title(r"$J = 1.307$", fontsize=24)



data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.309000_0.000000_4900.txt", skiprows=2)
axes[2].plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) ,  "*", c = "pink")
axes[2].set_title(r"$J = 1.309$", fontsize=24)

data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.310000_0.000000_4900.txt", skiprows=2)
axes[3].plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "*", c = "green")
axes[3].set_title(r"$J = 1.31$", fontsize=24)

for i in range(4):
    axes[i].set_xlabel(r"$ \langle cos\theta \rangle$", fontsize=22)
    axes[i].tick_params(axis='x', labelsize=22) 
    axes[i].tick_params(axis='y', labelsize=22) 
   
axes[1].set_ylim(axes[0].get_ylim())
axes[2].set_ylim(axes[0].get_ylim())
axes[3].set_ylim(axes[0].get_ylim())
        
plt.tight_layout()

plt.savefig("Thesis/Images/distr_cos_4900_J.png", bbox_inches='tight')

# %%
data_np = np.loadtxt("CPP/Distributions2/Counts_cos_1.320000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "*", c = "green")

# %%
data_np[0]
# Out:
# array([278.,   1.])

# %%
#os.chdir('CPP')
import matplotlib as mpl
#mpl.rc('image', cmap='gist_ncar')

plt.set_cmap('gist_ncar')


fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

files = sorted(list(glob.glob('CPP/ClusterUpdateFix2/rerun/Counts_E*_3600.txt')))
n = len(files)+1
#n=10

#color = plt.cm.hsv(0)
i=0
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=lines[1].split()[1]
    #if float(J)<1.5 : continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "s", color=color, label = r"J = "+ str(J), ms = 10)
    i+=1
plt.legend(loc="best", fontsize=20)

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


files = sorted(list(glob.glob('CPP/Simulations/Counts_E*_4900.txt')))
n = len(files)+1
#n=10


#plt.set_cmap('gist_ncar')
custom_palette = sns.color_palette("Paired", n)

i=0
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=lines[1].split()[1]
    if float(J)>1.45 : continue
    if float(J) < 1.41 : continue
    if float(J)==1.441: continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "s", color=custom_palette[i], label = r"J = "+ str(J), ms = 10)
    i+=1
plt.legend(loc="best", fontsize=20)

plt.title(r"Distribution of  $ \langle e \rangle$ for N = 4900 ", fontsize=22)

plt.xlabel(r'$  \langle e \rangle $', fontsize = 22)
# Out:
# Text(0.5, 0, '$  \\langle e \\rangle $')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

files = sorted(list(glob.glob('CPP/ClusterUpdateFix2/rerun/Counts_E*_2500.txt')))
n = len(files)+1
#n=10

plt.set_cmap('gist_ncar')

i=0
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=lines[1].split()[1]
    #if float(J)<1.5 : continue
    #if float(J)>1.4 : continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "s", color=color, label = r"J = "+ str(J), ms = 10)
    i+=1
plt.legend(loc="best", fontsize=20)

# %%
data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.380000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.390000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

# %%
data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.350000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.360000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.370000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.380000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.390000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.410000_0.000000_4900.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

# %%
data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.371000_0.000000_2500.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295", c = "purple", ms = 10)

# %%
data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.470000_0.000000_3600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

data_np = np.loadtxt("CPP/ClusterUpdateFix2/rerun/Counts_E_1.460000_0.000000_3600.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "*", label = r"J = 1.295",  ms = 10)

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


files = sorted(list(glob.glob('CPP/MainRUn/Counts_E*_2500.txt')))
n = len(files)+1
#n=10

Js = [ 1.31 , 1.32 , 1.344, 1.356, 1.36 ,
        1.372,   1.39 ,   1.41 ,  1.42 , 1.43 ,   1.44 ,
      1.45 , 1.46    ]

#plt.set_cmap('gist_ncar')
custom_palette = sns.color_palette("Paired", n)

markers = ["d", "v", "s", "*", "^", "p", "o", "D", "*", "^", ]
markers+=markers
markers+=markers

i=0
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=float(lines[1].split()[1])
    if (J not in Js): continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , markers[i], color=custom_palette[i], label = r"J = "+ str(J), ms = 8)
    i+=1
plt.legend(loc="best", fontsize=20)

plt.title(r"Distribution of  $ \langle e \rangle$ for N =  2500 ", fontsize=22)

plt.xlabel(r'$ | \langle e \rangle |$', fontsize = 22)

plt.grid()

plt.legend(loc="best", fontsize=20)

plt.savefig("Thesis/Images/distr_energy_2500.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


files = sorted(list(glob.glob('CPP/MainRUn/Counts_cos*_2500.txt')))
n = len(files)+1
#n=10

Js = [ 1.31 , 1.32 , 1.344, 1.356, 1.36 ,
        1.372,   1.39 ,  1.41 ,  1.42 , 1.43 ,   1.44 ,
         1.45 , 1.46   ]

#plt.set_cmap('gist_ncar')
custom_palette = sns.color_palette("Paired", n)

markers = ["d", "v", "s", "*", "^", "p", "o", "D", "*", "^", ]
markers+=markers
markers+=markers

i=0
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=float(lines[1].split()[1])
    if (J not in Js): continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , markers[i], color=custom_palette[i], label = r"J = "+ str(J), ms = 8)
    i+=1
plt.legend(loc="best", fontsize=20)

plt.title(r"Distribution of   $ \langle cos  \theta  \rangle $ for N =  2500 ", fontsize=22)

plt.xlabel(r'$  \langle cos \theta \rangle  $', fontsize = 22)

plt.grid()

plt.legend(loc="best", fontsize=20)


plt.savefig("Thesis/Images/distr_cos_2500.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


files = sorted(list(glob.glob('CPP/MainRUn/Counts_E*_4900.txt')))
n = len(files)+1
#n=10


Js = [ 1.31 , 1.32 , 1.344, 1.356, 1.36 ,
        1.372,   1.39 ,  1.41 ,  1.42 , 1.43 ,   1.44 ,
         1.45 , 1.46   ]

#plt.set_cmap('gist_ncar')
custom_palette = sns.color_palette("Paired", n)

markers = ["d", "v", "s", "*", "^", "p", "o", "D", "*", "^", ]
markers+=markers
markers+=markers

i=0
k=0
for file in files:
    k+=1
    f=open(file)
    lines=f.readlines()
    J=float(lines[1].split()[1])
    #if (J not in Js): continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    if(k%2==0):  continue 
    plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , markers[i], color=custom_palette[i], label = r"J = "+ str(J), ms = 8)
    i+=1
plt.legend(loc="best", fontsize=20)

plt.title(r"Distribution of  $ | \langle e \rangle | $ for N =  4900 ", fontsize=22)

plt.xlabel(r'$ | \langle e \rangle | $', fontsize = 22)

plt.grid()

plt.legend(loc="best", fontsize=20)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22)
#plt.savefig("/home/kamilla/SAW")
#plt.savefig("/home/kamilla//img/distr_energy_4900.png", bbox_inches='tight') 

plt.ylabel('Density', fontsize = 22)

plt.savefig("/Users/kamillafaizullina/Desktop/SAW/XY_AFterReview/img/distr_energy_4900.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


files = sorted(list(glob.glob('CPP/MainRUn/Counts_cos*_4900.txt')))
n = len(files)+1
#n=10

Js = [ 1.31 , 1.32 , 1.344, 1.356, 1.36 ,
        1.372,   1.39 , 1.405,  1.41 ,  1.42 , 1.43 ,   1.44 ,
       1.441, 1.45 , 1.46   ]

#plt.set_cmap('gist_ncar')
custom_palette = sns.color_palette("Paired", n)

markers = ["d", "v", "s", "*", "^", "p", "o", "D", "*", "^", ]
markers+=markers
markers+=markers

i=0
k=0
for file in files:   
    k+=1
    f=open(file)
    lines=f.readlines()
    J=float(lines[1].split()[1])
    #if (J not in Js): continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    if(k%2==0):  continue 
    plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , markers[i], color=custom_palette[i], label = r"J = "+ str(J), ms = 8)
    i+=1
plt.legend(loc="best", fontsize=20)

plt.title(r"Distribution of  $ \langle cos \theta \rangle  $ for N =  4900 ", fontsize=22)

plt.xlabel(r'$  \langle cos \theta \rangle $', fontsize = 22)
plt.ylabel('Density', fontsize = 22)
plt.grid()

plt.legend(loc="best", fontsize=20)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 

plt.savefig("/Users/kamillafaizullina/Desktop/SAW/XY_AFterReview/img/distr_cos_4900.png", bbox_inches='tight')
