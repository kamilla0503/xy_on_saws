# %%
import matplotlib.pyplot as plt
import random
import numpy as np

import pandas as pd
from matplotlib.ticker import LogFormatter 
from scipy.optimize import curve_fit
from pathlib import Path
import matplotlib.colors
from matplotlib import ticker, cm
import pickle

import os                                                                   
import glob


from scipy.stats import norm
#%matplotlib notebook

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_E_0.860000_0.000000_550.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.86")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_E_0.870000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.87")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_E_0.880000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.88")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_E_0.890000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.89")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_E_0.900000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.9")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_E_0.910000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.91")


plt.title(r"Distribution of $\langle e \rangle $ for N = 700 ", fontsize=22)

plt.xlabel(r'$ e$', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)

plt.savefig("Thesis/Images/distr_energy_700.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_cos_0.860000_0.000000_550.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.86")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_cos_0.870000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.87")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_cos_0.880000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.88")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_cos_0.890000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.89")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_cos_0.900000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.9")

data_np = np.loadtxt("CPP_3D/Results/LongerIteration1/Counts_cos_0.910000_0.000000_700.txt", skiprows=2)
plt.plot(data_np[:, 0]*0.001-1, data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.91")


plt.title(r"Distribution of $\langle e \rangle $ for N = 700 ", fontsize=22)

plt.xlabel(r'$ e$', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)

plt.savefig("Thesis/Images/distr_cos_700.png", bbox_inches='tight')

# %%
import matplotlib as mpl
#mpl.rc('image', cmap='gist_ncar')

plt.set_cmap('gist_ncar')


fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

files = sorted(list(glob.glob('CPP_3D/Results/Short/Counts_E*_300.txt')))
 
#files = sorted(list(glob.glob('CPP_3D/Results/LongerIteration1/Counts_E*_700.txt')))
#files = sorted(list(glob.glob('CPP_3D/Results/Iteration00/Counts_E*_300.txt')))
n = len(files)+1
#n=10
#color = plt.cm.hsv(0)
i=0
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=lines[1].split()[1]
    if float(J)>1.05 : continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "s",  label = r"J = "+ str(J), ms = 10)
    i+=1
    
    
files = sorted(list(glob.glob('CPP_3D/Results/Iteration00/Counts_E*_300.txt')))
n = len(files)+1
#n=10
#color = plt.cm.hsv(0)
i=0
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=lines[1].split()[1]
    if float(J)>1.05 : continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "*",  label = r"J = "+ str(J), ms = 10)
    i+=1    
    
    
plt.legend(loc="best", fontsize=20)

# %%
import matplotlib as mpl
#mpl.rc('image', cmap='gist_ncar')

plt.set_cmap('gist_ncar')


fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

files = sorted(list(glob.glob('CPP_3D/Results/Long/Counts_cos*0.83*.txt')))
#files = sorted(list(glob.glob('CPP_3D/Results/LongerIteration1/Counts_E*_700.txt')))
#files = sorted(list(glob.glob('CPP_3D/Results/Iteration00/Counts_E*_300.txt')))
n = len(files)+1
#n=10

#color = plt.cm.hsv(0)
i=0
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=lines[1].split()[1]
    if float(J)>1.35 : continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "s",  label = r"J = "+ str(J), ms = 10)
    i+=1
plt.legend(loc="best", fontsize=20)

# %%
import matplotlib as mpl
#mpl.rc('image', cmap='gist_ncar')

plt.set_cmap('gist_ncar')


fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

files = sorted(list(glob.glob('CPP_3D/Results/Long/Counts_E*_400.txt')))
 
#files = sorted(list(glob.glob('CPP_3D/Results/LongerIteration1/Counts_E*_700.txt')))
#files = sorted(list(glob.glob('CPP_3D/Results/Iteration00/Counts_E*_300.txt')))
n = len(files)+1
#n=10
#color = plt.cm.hsv(0)
i=0
Js = []
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=lines[1].split()[1]
    if float(J)>1.05 : continue
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    Js.append(float(J))
    plt.plot((data_np[:, 0]*0.001-2), data_np[:,1]/np.sum( data_np[:,1]) ,  "s",  label = r"J = "+ str(J), ms = 10)
    i+=1
    
    
files = sorted(list(glob.glob('CPP_3D/Results/LongerIteration1/Counts_E*_400.txt')))
n = len(files)+1
#n=10
#color = plt.cm.hsv(0)
i=0
print(Js)
for file in files:   
    f=open(file)
    lines=f.readlines()
    J=float(lines[1].split()[1])
 
    if float(J)>1.05 : continue
    if J not in Js: continue
         
    color = plt.cm.hsv(i/(n-1))
    data_np = np.loadtxt(file, skiprows=2)
    #plt.plot(data_np[:, 0]*0.001-2, data_np[:,1]/np.sum( data_np[:,1]) ,  "*",  label = r"J = "+ str(J), ms = 10)
    i+=1    
    
    
plt.legend(loc="best", fontsize=20)
# Out:
# [0.83, 0.84, 0.85, 0.86, 0.87, 0.871, 0.873, 0.876, 0.879, 0.88, 0.881, 0.882, 0.885, 0.888, 0.89, 0.891, 0.894, 0.895, 0.898, 0.9, 0.901, 0.904, 0.91, 0.92, 0.93]
